# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from config import username, password, host, port
import requests

# %%
# create an engine that can connect to local database
engine = create_engine(f"postgresql://{username}:{password}@{host}:{port}/postgres")
conn=engine.connect()

# %%
##read in salaries and their count from sql
billionaire_list = pd.read_sql('SELECT * FROM billionaires group by name order by name;',conn)

# %%
billionaire_list
# Out:
#         id                          name  rank  year company_founded  \
# 0        1          A. Jerrold Perenchio   663  2014            1955
# 1        2            Abdulla Al Futtaim   687  2014            1930
# 2        3  Abdulla bin Ahmad Al Ghurair   305  2014            1960
# 3        4             Abdullah Al Rajhi   731  2014            1957
# 4        5              Abdulsamad Rabiu  1372  2014            1988
# ...    ...                           ...   ...   ...             ...
# 1648  1649                     Zhu Yicai  1154  2014            1993
# 1649  1650                 Ziyad Manasir   609  2014            1992
# 1650  1651            Ziyaudin Magomedov  1372  2014            2004
# 1651  1652                  Zong Qinghou    94  2014            1987
# 1652  1653            Zygmunt Solorz-Zak   446  2014            1992
#
#                company_name     company_relationship        company_sector  \
# 0                 Univision  former chairman and CEO                 media
# 1          Al-Futtaim Group                 relation               trading
# 2          Al-Ghurair Group                 relation      industrial goods
# 3             Al Rajhi bank                  founder               Banking
# 4                 BUA Group                  founder  sugar, flour, cement
# ...                     ...                      ...                   ...
# 1648             Yurun Food                  founder         meat products
# 1649     Stroygazconsulting                  founder          construction
# 1650            Summa Group                  founder            ports, gas
# 1651  Hangzhou Wahaha Group                  founder             beverages
# 1652                 Polsat                  founder            television
#
#      company_type  demographics_age  ... location_gdp  \
# 0         aquired                83  ...          0.0
# 1             new                 0  ...          0.0
# 2             new                 0  ...          0.0
# 3             new                 0  ...          0.0
# 4             new                54  ...          0.0
# ...           ...               ...  ...          ...
# 1648          new                49  ...          0.0
# 1649          new                48  ...          0.0
# 1650          new                45  ...          0.0
# 1651          new                68  ...          0.0
# 1652          new                57  ...          0.0
#
#                location_region               wealth_type  \
# 0                North America                 executive
# 1     Middle East/North Africa                 inherited
# 2     Middle East/North Africa                 inherited
# 3     Middle East/North Africa         self-made finance
# 4           Sub-Saharan Africa       founder non-finance
# ...                        ...                       ...
# 1648                 East Asia         self-made finance
# 1649                    Europe  privatized and resources
# 1650                    Europe  privatized and resources
# 1651                 East Asia       founder non-finance
# 1652                    Europe       founder non-finance
#
#       wealth_worth_in_billions wealth_how_category wealth_how_from_emerging  \
# 0                          2.6  Non-Traded Sectors                     TRUE
# 1                          2.5  Non-Traded Sectors                     TRUE
# 2                          4.8           Financial                     TRUE
# 3                          2.4           Financial                     TRUE
# 4                          1.2      Traded Sectors                     TRUE
# ...                        ...                 ...                      ...
# 1648                       1.5           Financial                     TRUE
# 1649                       2.8  Non-Traded Sectors                     TRUE
# 1650                       1.2    Resource Related                     TRUE
# 1651                      11.6      Traded Sectors                     TRUE
# 1652                       3.5  Non-Traded Sectors                     TRUE
#
#         wealth_how_industry wealth_how_inherited wealth_how_was_founder  \
# 0                     Media        not inherited                   TRUE
# 1        Retail, Restaurant               father                   TRUE
# 2     Diversified financial               father                   TRUE
# 3          Money Management        not inherited                   TRUE
# 4                  Consumer        not inherited                   TRUE
# ...                     ...                  ...                    ...
# 1648  Diversified financial        not inherited                   TRUE
# 1649            Constrution        not inherited                   TRUE
# 1650                 Energy        not inherited                   TRUE
# 1651               Consumer        not inherited                   TRUE
# 1652                  Media        not inherited                   TRUE
#
#      wealth_how_was_political
# 0                        TRUE
# 1                        TRUE
# 2                        TRUE
# 3                        TRUE
# 4                        TRUE
# ...                       ...
# 1648                     TRUE
# 1649                     TRUE
# 1650                     TRUE
# 1651                     TRUE
# 1652                     TRUE
#
# [1653 rows x 23 columns]

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "768", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)

# %%
data=response.text

# %%
parsed=json.loads(data)
results=parsed['results']

# %%
print(json.dumps(parsed, indent=4))
# Out:
# {
#     "meta": {
#         "total_record_count": 38384,
#         "total_pages": 768,
#         "current_page": 768,
#         "per_page": 50
#     },
#     "query_id": "FitlMkibIDGTETG5d4zIuWpnIH0GXPbACCXQCxDfhAW0aj6fYnPObgYTmLkNE9tGZhRYrpoDg4U1dOoEwg==",
#     "query": {
#         "urlsafe_query_hash": "FitlMkibIDGTETG5d4zIuWpnIH0GXPbACCXQCxDfhAW0aj6fYnPObgYTmLkNE9tGZhRYrpoDg4U1dOoEwg==",
#         "dataset": "investor",
#         "filter": {
#             "investor_id": {
#                 "gte": 0
#             }
#         },
#         "sort": null
#     },
#     "results": [
#         {
#             "investor_id": 30078,
#             "name": "Presence Capital",
#             "investor_domain": "presencecap.com",
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": "2016-01-04",
#             "type": "vc",
#             "most_recent_deal": "2018-06-28",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": "presencecap.com",
#             "mm_slug": "presence-capital",
#             "deals_per_company": 1.1,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 488,
#             "name": "ARC Angel Fund",
#             "investor_domain": "arcangelfund.com",
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": "2016-04-26",
#             "type": "other",
#             "most_recent_deal": "2018-01-31",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": "arcangelfund.com",
#             "mm_slug": "ARC",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 1761,
#             "name": "Ascent Venture Partners",
#             "investor_domain": "ascentvp.com",
#             "location": "Boston",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": "2016-08-15",
#             "type": "vc",
#             "most_recent_deal": "2018-04-12",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": "Boston",
#             "state": "MA",
#             "country": "USA",
#             "website": "ascentvp.com",
#             "mm_slug": "ascent-venture-partners",
#             "deals_per_company": 1.5,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 116,
#             "name": "Baseline Ventures",
#             "investor_domain": "baselinev.com",
#             "location": "Bay Area",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": "2018-03-13",
#             "type": "vc",
#             "most_recent_deal": "2020-07-20",
#             "number_of_deals": 182,
#             "portfolio_size": 113,
#             "avg_growth_score": 133.90384615384616,
#             "zip": null,
#             "city": "San Francisco",
#             "state": "CA",
#             "country": "USA",
#             "website": "baselinev.com",
#             "mm_slug": "BaselineVentures",
#             "deals_per_company": 1.5,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 1968,
#             "name": "Discovery Capital",
#             "investor_domain": "discoverycapital.com",
#             "location": "Vancouver",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2019-11-25",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": "Vancouver",
#             "state": "CAN-BC",
#             "country": "CAN",
#             "website": "discoverycapital.com",
#             "mm_slug": "discovery-capital",
#             "deals_per_company": 1.2,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 20199,
#             "name": "East West Bank",
#             "investor_domain": "eastwestbank.com",
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "pe",
#             "most_recent_deal": "2018-12-13",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": "eastwestbank.com",
#             "mm_slug": "east-west-bank",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 7877,
#             "name": "Portland Seed Fund",
#             "investor_domain": "portlandseedfund.com",
#             "location": "Portland",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2020-08-04",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": "97205",
#             "city": "Portland",
#             "state": "OR",
#             "country": "USA",
#             "website": "portlandseedfund.com",
#             "mm_slug": "portland-seed-fund",
#             "deals_per_company": 1.2,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 31879,
#             "name": "JetBlue Technology Ventures",
#             "investor_domain": "jetblueventures.com",
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2018-11-01",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": "jetblueventures.com",
#             "mm_slug": "jetblue-technology-ventures",
#             "deals_per_company": 1.1,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 38748,
#             "name": "Boeing",
#             "investor_domain": "boeing.com",
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "strategic",
#             "most_recent_deal": "2019-10-08",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": "boeing.com",
#             "mm_slug": "boeing",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 38407,
#             "name": "Harpeth Capital",
#             "investor_domain": "harpethcapital.com",
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2017-03-19",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": "harpethcapital.com",
#             "mm_slug": "harpeth-capital",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 23403,
#             "name": "Wibecke Nagell-Erichsen",
#             "investor_domain": null,
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "angel",
#             "most_recent_deal": "2014-08-19",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": null,
#             "mm_slug": "wibecke-nagell-erichsen",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 56776,
#             "name": "Pegasus Tech Ventures",
#             "investor_domain": "https://www.pegasustechventures.com/",
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2020-07-08",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": "https://www.pegasustechventures.com/",
#             "mm_slug": "pegasus-tech-ventures",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 1677,
#             "name": "Emerald Technology Ventures ",
#             "investor_domain": "emerald-ventures.com",
#             "location": "Zurich",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2020-06-24",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": "Zurich",
#             "state": null,
#             "country": "SWE",
#             "website": "emerald-ventures.com",
#             "mm_slug": "emerald-technology-ventures",
#             "deals_per_company": 1.6,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 16097,
#             "name": "350 Investment Partners",
#             "investor_domain": "350ip.co.uk",
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2013-10-03",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": "350ip.co.uk",
#             "mm_slug": "350-investment-partners",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 37168,
#             "name": "Loeb Partners",
#             "investor_domain": "loebpartners.com",
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2018-01-11",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": "loebpartners.com",
#             "mm_slug": "loeb-partners",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 51745,
#             "name": "Greycroft's Tracker fund",
#             "investor_domain": null,
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2018-07-18",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": null,
#             "mm_slug": "greycrofts-tracker-fund",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 200,
#             "name": "Vulcan Capital",
#             "investor_domain": "capital.vulcan.com",
#             "location": "Seattle",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2020-09-30",
#             "number_of_deals": 151,
#             "portfolio_size": 112,
#             "avg_growth_score": 574.3663366336634,
#             "zip": null,
#             "city": "Seattle",
#             "state": "WA",
#             "country": "USA",
#             "website": "capital.vulcan.com",
#             "mm_slug": "Vulcan-Capital",
#             "deals_per_company": 1.3,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 34912,
#             "name": "UCCVR",
#             "investor_domain": "uccvr.com",
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2016-09-01",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": "uccvr.com",
#             "mm_slug": "uccvr",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 17444,
#             "name": "Streamlined Ventures",
#             "investor_domain": "streamlinedventures.com",
#             "location": "Bay Area",
#             "three_year_funds_offered": 34575000,
#             "three_year_funds_sold": 4575000,
#             "est_most_recent_fund_date": "2019-01-07",
#             "type": "vc",
#             "most_recent_deal": "2020-05-07",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": "San Francisco",
#             "state": "CA",
#             "country": "USA",
#             "website": "streamlinedventures.com",
#             "mm_slug": "streamlined-ventures",
#             "deals_per_company": 1.1,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 19231,
#             "name": "Angel Academe",
#             "investor_domain": "angelacade.me",
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2018-10-17",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": "angelacade.me",
#             "mm_slug": "angel-academe-vc",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 9962,
#             "name": "Khailee Ng",
#             "investor_domain": null,
#             "location": "MYS",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "angel",
#             "most_recent_deal": "2015-10-30",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": "MYS",
#             "website": "angel.co/khailee",
#             "mm_slug": "KhaileeNg",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 49980,
#             "name": " Audeo Capital",
#             "investor_domain": null,
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2018-05-31",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": null,
#             "mm_slug": "audeo-capital",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 18978,
#             "name": "Boyu Capital",
#             "investor_domain": "boyucapital.com",
#             "location": "Hong Kong",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": "2014-02-26",
#             "type": "vc",
#             "most_recent_deal": "2020-07-20",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": "Hong Kong",
#             "state": null,
#             "country": "CHN",
#             "website": "boyucapital.com",
#             "mm_slug": "boyu-capital",
#             "deals_per_company": 1.1,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 20699,
#             "name": "Deerfield Management Company",
#             "investor_domain": "deerfield.com",
#             "location": "New York",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2020-07-07",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": "New York",
#             "state": "NY",
#             "country": "USA",
#             "website": "deerfield.com",
#             "mm_slug": "Deerfield",
#             "deals_per_company": 1.1,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 457,
#             "name": "Rose Tech Ventures",
#             "investor_domain": "rose.vc",
#             "location": "New York",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2015-10-08",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": "New York",
#             "state": "NY",
#             "country": "USA",
#             "website": "rose.vc",
#             "mm_slug": "rose-tech-ventures",
#             "deals_per_company": 1.4,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 8503,
#             "name": "Deborah Quazzo",
#             "investor_domain": null,
#             "location": "Chicago",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "angel",
#             "most_recent_deal": "2018-10-09",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": "Chicago",
#             "state": "IL",
#             "country": "USA",
#             "website": "angel.co/deborah-quazzo",
#             "mm_slug": "DeborahQuazzo",
#             "deals_per_company": 1.2,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 37707,
#             "name": "Bow Capital",
#             "investor_domain": "bowcapital.com",
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2018-12-10",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": "bowcapital.com",
#             "mm_slug": "bow-capital",
#             "deals_per_company": 1.2,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 21109,
#             "name": "Toba Capital",
#             "investor_domain": "tobacapital.com",
#             "location": "Bay Area",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2020-09-03",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": "San Francisco",
#             "state": "CA",
#             "country": "USA",
#             "website": "tobacapital.com",
#             "mm_slug": "toba-capital",
#             "deals_per_company": 1.4,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 77,
#             "name": "Sigma Partners",
#             "investor_domain": "sigmapartners.com",
#             "location": "Bay Area",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2018-12-13",
#             "number_of_deals": 276,
#             "portfolio_size": 135,
#             "avg_growth_score": 365.4186046511628,
#             "zip": null,
#             "city": "Danville",
#             "state": "CA",
#             "country": "USA",
#             "website": "sigmapartners.com",
#             "mm_slug": "sigma-partners",
#             "deals_per_company": 2.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 13670,
#             "name": "H-FARM Ventures",
#             "investor_domain": "h-farmventures.com",
#             "location": "Roncade",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2018-01-24",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": "31056",
#             "city": "Roncade",
#             "state": null,
#             "country": "ITA",
#             "website": "h-farmventures.com",
#             "mm_slug": "h-farm-ventures",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 50374,
#             "name": "Tus-Holdings",
#             "investor_domain": null,
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2018-06-11",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": null,
#             "mm_slug": "tus-holdings",
#             "deals_per_company": 1.0,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 27,
#             "name": "InterWest Partners",
#             "investor_domain": "interwest.com",
#             "location": "Bay Area",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2019-11-13",
#             "number_of_deals": 318,
#             "portfolio_size": 200,
#             "avg_growth_score": 117.04255319148936,
#             "zip": null,
#             "city": "Menlo Park",
#             "state": "CA",
#             "country": "USA",
#             "website": "interwest.com",
#             "mm_slug": "InterWest",
#             "deals_per_company": 1.5,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 13505,
#             "name": "Y Combinator",
#             "investor_domain": "ycombinator.com",
#             "location": "Bay Area",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": "2016-04-01",
#             "type": "accelerator",
#             "most_recent_deal": "2020-02-27",
#             "number_of_deals": 2310,
#             "portfolio_size": 1282,
#             "avg_growth_score": 35.02735042735043,
#             "zip": "94041",
#             "city": "Mountain View",
#             "state": "CA",
#             "country": "USA",
#             "website": "ycombinator.com",
#             "mm_slug": "YC",
#             "deals_per_company": 1.7,
#             "resource_type": "resultproxy"
#         },
#         {
#             "investor_id": 17329,
#             "name": "Vy Capital",
#             "investor_domain": "vycapital.com",
#             "location": null,
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "vc",
#             "most_recent_deal": "2020-07-15",
#             "number_of_deals": 0,
#             "portfolio_size": 0,
#             "avg_growth_score": 0,
#             "zip": null,
#             "city": null,
#             "state": null,
#             "country": null,
#             "website": "vycapital.com",
#             "mm_slug": "vy-capital",
#             "deals_per_company": 1.2,
#             "resource_type": "resultproxy"
#         }
#     ]
# }

# %%
with open('results.json', 'w') as f:
    json.dump(results, f)

# %%
investors_df = pd.read_json('results.json')

# %%
investors_df.head()
# Out:
#    investor_id                     name       investor_domain   location  \
# 0        30078         Presence Capital       presencecap.com       None
# 1          488           ARC Angel Fund      arcangelfund.com       None
# 2         1761  Ascent Venture Partners          ascentvp.com     Boston
# 3          116        Baseline Ventures         baselinev.com   Bay Area
# 4         1968        Discovery Capital  discoverycapital.com  Vancouver
#
#    three_year_funds_offered  three_year_funds_sold est_most_recent_fund_date  \
# 0                         0                      0                2016-01-04
# 1                         0                      0                2016-04-26
# 2                         0                      0                2016-08-15
# 3                         0                      0                2018-03-13
# 4                         0                      0                      None
#
#     type most_recent_deal  number_of_deals  portfolio_size  avg_growth_score  \
# 0     vc       2018-06-28                0               0          0.000000
# 1  other       2018-01-31                0               0          0.000000
# 2     vc       2018-04-12                0               0          0.000000
# 3     vc       2020-07-20              182             113        133.903846
# 4     vc       2019-11-25                0               0          0.000000
#
#    zip           city   state country               website  \
# 0  NaN           None    None    None       presencecap.com
# 1  NaN           None    None    None      arcangelfund.com
# 2  NaN         Boston      MA     USA          ascentvp.com
# 3  NaN  San Francisco      CA     USA         baselinev.com
# 4  NaN      Vancouver  CAN-BC     CAN  discoverycapital.com
#
#                    mm_slug  deals_per_company resource_type
# 0         presence-capital                1.1   resultproxy
# 1                      ARC                1.0   resultproxy
# 2  ascent-venture-partners                1.5   resultproxy
# 3         BaselineVentures                1.5   resultproxy
# 4        discovery-capital                1.2   resultproxy

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "767", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df1 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "766", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df2 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "765", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df3 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "764", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df4 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "763", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df5 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "762", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df6 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "761", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df7 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "760", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df8 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "759", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df9 = pd.read_json('results.json')

# %%
df1=pd.concat([investors_df, investors_df1, investors_df2, investors_df3, investors_df4, investors_df5, investors_df6, investors_df7, investors_df8, investors_df9])
print(len(df1))
# Out:
# 484

# %%
df1.reset_index()
# Out:
#      index  investor_id                      name       investor_domain  \
# 0        0        30078          Presence Capital       presencecap.com
# 1        1          488            ARC Angel Fund      arcangelfund.com
# 2        2         1761   Ascent Venture Partners          ascentvp.com
# 3        3          116         Baseline Ventures         baselinev.com
# 4        4         1968         Discovery Capital  discoverycapital.com
# ..     ...          ...                       ...                   ...
# 479     45        20997            Dale Dougherty                  None
# 480     46         2207  Asset Management Company   amcfamilyoffice.com
# 481     47         8274                Scott Cook                  None
# 482     48        29223       Broad Strategy Fund                  None
# 483     49        18036      Andreas Bechtolsheim                  None
#
#       location  three_year_funds_offered  three_year_funds_sold  \
# 0         None                         0                      0
# 1         None                         0                      0
# 2       Boston                         0                      0
# 3     Bay Area                         0                      0
# 4    Vancouver                         0                      0
# ..         ...                       ...                    ...
# 479       None                         0                      0
# 480       None                         0                      0
# 481    Atlanta                         0                      0
# 482       None                         0                      0
# 483       None                         0                      0
#
#     est_most_recent_fund_date   type most_recent_deal  ...  portfolio_size  \
# 0                  2016-01-04     vc       2018-06-28  ...               0
# 1                  2016-04-26  other       2018-01-31  ...               0
# 2                  2016-08-15     vc       2018-04-12  ...               0
# 3                  2018-03-13     vc       2020-07-20  ...             113
# 4                        None     vc       2019-11-25  ...               0
# ..                        ...    ...              ...  ...             ...
# 479                      None  angel       2014-05-30  ...               0
# 480                      None     vc       2014-01-28  ...               0
# 481                      None  angel       2020-03-10  ...               0
# 482                      None  other       2014-01-28  ...               0
# 483                      None  angel       2014-01-20  ...               0
#
#      avg_growth_score  zip           city   state country  \
# 0            0.000000  NaN           None    None    None
# 1            0.000000  NaN           None    None    None
# 2            0.000000  NaN         Boston      MA     USA
# 3          133.903846  NaN  San Francisco      CA     USA
# 4            0.000000  NaN      Vancouver  CAN-BC     CAN
# ..                ...  ...            ...     ...     ...
# 479          0.000000  NaN           None    None    None
# 480          0.000000  NaN           None    None    None
# 481          0.000000  NaN        Atlanta      GA     USA
# 482          0.000000  NaN           None    None    None
# 483          0.000000  NaN           None    None    None
#
#                   website                    mm_slug deals_per_company  \
# 0         presencecap.com           presence-capital               1.1
# 1        arcangelfund.com                        ARC               1.0
# 2            ascentvp.com    ascent-venture-partners               1.5
# 3           baselinev.com           BaselineVentures               1.5
# 4    discoverycapital.com          discovery-capital               1.2
# ..                    ...                        ...               ...
# 479                  None              DaleDougherty               1.0
# 480   amcfamilyoffice.com  asset-management-company                1.4
# 481   angel.co/scott-cook                  ScottCook               1.3
# 482                  None        broad-strategy-fund               1.0
# 483                  None        AndreasBechtolsheim               1.0
#
#      resource_type
# 0      resultproxy
# 1      resultproxy
# 2      resultproxy
# 3      resultproxy
# 4      resultproxy
# ..             ...
# 479    resultproxy
# 480    resultproxy
# 481    resultproxy
# 482    resultproxy
# 483    resultproxy
#
# [484 rows x 21 columns]

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "758", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df10 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "757", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df11 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "756", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df12 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "755", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df13 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "754", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df14 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "753", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df15 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "752", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df16 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "751", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df17 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "750", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df18 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "749", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df19 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "748", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df20 = pd.read_json('results.json')

# %%
df2=pd.concat([df1, investors_df10, investors_df11, investors_df12, investors_df13, investors_df14, investors_df15, investors_df16, investors_df17, investors_df18, investors_df19, investors_df20])
print(len(df2))
# Out:
# 1034

# %%
df3 = df2.dropna(subset=['city','country'])
print(len(df3))
# Out:
# 332

# %%
df3.reset_index()
# Out:
#      index  investor_id                          name       investor_domain  \
# 0        2         1761       Ascent Venture Partners          ascentvp.com
# 1        3          116             Baseline Ventures         baselinev.com
# 2        4         1968             Discovery Capital  discoverycapital.com
# 3        6         7877            Portland Seed Fund  portlandseedfund.com
# 4       12         1677  Emerald Technology Ventures   emerald-ventures.com
# ..     ...          ...                           ...                   ...
# 327     32         2125        Stata Venture Partners                  None
# 328     37         7668                 Evan Williams                  None
# 329     39         8623              George Kliavkoff                  None
# 330     43         1615                    Shan Mehta                  None
# 331     44         8577                  Adii Pienaar                  None
#
#       location  three_year_funds_offered  three_year_funds_sold  \
# 0       Boston                         0                      0
# 1     Bay Area                         0                      0
# 2    Vancouver                         0                      0
# 3     Portland                         0                      0
# 4       Zurich                         0                      0
# ..         ...                       ...                    ...
# 327     Boston                         0                      0
# 328   Bay Area                         0                      0
# 329   New York                         0                      0
# 330   Bay Area                         0                      0
# 331  Cape Town                         0                      0
#
#     est_most_recent_fund_date   type most_recent_deal  ...  portfolio_size  \
# 0                  2016-08-15     vc       2018-04-12  ...               0
# 1                  2018-03-13     vc       2020-07-20  ...             113
# 2                        None     vc       2019-11-25  ...               0
# 3                        None     vc       2020-08-04  ...               0
# 4                        None     vc       2020-06-24  ...               0
# ..                        ...    ...              ...  ...             ...
# 327                      None     vc       2016-11-15  ...               0
# 328                      None  angel       2016-10-20  ...               0
# 329                      None  angel       2012-10-15  ...               0
# 330                      None  angel       2015-02-25  ...               0
# 331                      None  angel       2013-08-01  ...               0
#
#      avg_growth_score      zip           city   state country  \
# 0            0.000000      NaN         Boston      MA     USA
# 1          133.903846      NaN  San Francisco      CA     USA
# 2            0.000000      NaN      Vancouver  CAN-BC     CAN
# 3            0.000000  97205.0       Portland      OR     USA
# 4            0.000000      NaN         Zurich    None     SWE
# ..                ...      ...            ...     ...     ...
# 327          0.000000      NaN         Boston      MA     USA
# 328          0.000000      NaN  San Francisco      CA     USA
# 329          0.000000      NaN       New York      NY     USA
# 330          0.000000      NaN  San Francisco      CA     USA
# 331          0.000000      NaN      Cape Town    None     ZAF
#
#                   website                      mm_slug deals_per_company  \
# 0            ascentvp.com      ascent-venture-partners               1.5
# 1           baselinev.com             BaselineVentures               1.5
# 2    discoverycapital.com            discovery-capital               1.2
# 3    portlandseedfund.com           portland-seed-fund               1.2
# 4    emerald-ventures.com  emerald-technology-ventures               1.6
# ..                    ...                          ...               ...
# 327                  None       stata-venture-partners               2.3
# 328           angel.co/ev                 EvanWilliams               1.1
# 329    angel.co/kliavkoff              GeorgeKliavkoff               2.0
# 330   angel.co/shan-mehta                    ShanMehta               1.0
# 331                  None                  AdiiPienaar               1.0
#
#      resource_type
# 0      resultproxy
# 1      resultproxy
# 2      resultproxy
# 3      resultproxy
# 4      resultproxy
# ..             ...
# 327    resultproxy
# 328    resultproxy
# 329    resultproxy
# 330    resultproxy
# 331    resultproxy
#
# [332 rows x 21 columns]

# %%
df4=df3[["investor_id", "name", "location", "type", "most_recent_deal", "number_of_deals", "portfolio_size", "city", "state",
         "country", "website"
]]
print(len(df3))
# Out:
# 332

# %%
df4['industry'] ='food & beverages'
# Out:
# C:\Users\ssbne\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final_investors_df = df4
final_investors_df
# Out:
#     investor_id                          name   location   type  \
# 2          1761       Ascent Venture Partners     Boston     vc
# 3           116             Baseline Ventures   Bay Area     vc
# 4          1968             Discovery Capital  Vancouver     vc
# 6          7877            Portland Seed Fund   Portland     vc
# 12         1677  Emerald Technology Ventures      Zurich     vc
# ..          ...                           ...        ...    ...
# 32         2125        Stata Venture Partners     Boston     vc
# 37         7668                 Evan Williams   Bay Area  angel
# 39         8623              George Kliavkoff   New York  angel
# 43         1615                    Shan Mehta   Bay Area  angel
# 44         8577                  Adii Pienaar  Cape Town  angel
#
#    most_recent_deal  number_of_deals  portfolio_size           city   state  \
# 2        2018-04-12                0               0         Boston      MA
# 3        2020-07-20              182             113  San Francisco      CA
# 4        2019-11-25                0               0      Vancouver  CAN-BC
# 6        2020-08-04                0               0       Portland      OR
# 12       2020-06-24                0               0         Zurich    None
# ..              ...              ...             ...            ...     ...
# 32       2016-11-15                0               0         Boston      MA
# 37       2016-10-20                0               0  San Francisco      CA
# 39       2012-10-15                0               0       New York      NY
# 43       2015-02-25                0               0  San Francisco      CA
# 44       2013-08-01                0               0      Cape Town    None
#
#    country               website          industry
# 2      USA          ascentvp.com  food & beverages
# 3      USA         baselinev.com  food & beverages
# 4      CAN  discoverycapital.com  food & beverages
# 6      USA  portlandseedfund.com  food & beverages
# 12     SWE  emerald-ventures.com  food & beverages
# ..     ...                   ...               ...
# 32     USA                  None  food & beverages
# 37     USA           angel.co/ev  food & beverages
# 39     USA    angel.co/kliavkoff  food & beverages
# 43     USA   angel.co/shan-mehta  food & beverages
# 44     ZAF                  None  food & beverages
#
# [332 rows x 12 columns]

# %%
final_investors_df.to_csv("Data Sets/api1.csv")

# %%
# create an engine that can connect to local database
engine = create_engine(f"postgresql://{username}:{password}@{host}:{port}/postgres")
conn=engine.connect()

# %%
##read in salaries and their count from sql
sharkTank_list = pd.read_sql('SELECT * FROM sharktank;',conn)

# %%
sharkTank_list
# Out:
#        id   deal                                        description  episode  \
# 0    None  False             Bluetooth device implant for your ear.        1
# 1    None   True  Retail and wholesale pie factory with two reta...        1
# 2    None   True  Ava the Elephant is a godsend for frazzled par...        1
# 3    None  False  Organizing, packing, and moving services deliv...        1
# 4    None  False  Interactive media centers for healthcare waiti...        1
# ..    ...    ...                                                ...      ...
# 490  None   True  Zoom Interiors is a virtual service for interi...       28
# 491  None   True  Spikeball started out as a casual outdoors gam...       29
# 492  None   True  Shark Wheel is out to literally reinvent the w...       29
# 493  None  False  Adriana Montano wants to open the first Cat Ca...       29
# 494  None   True  Sway Motorsports makes a three-wheeled, all-el...       29
#
#                 category                                      entrepreneurs  \
# 0              Novelties                                     Darrin Johnson
# 1         Specialty Food                                         Tod Wilson
# 2    Baby and Child Care                                    Tiffany Krumins
# 3      Consumer Services                        Nick Friedman, Omar Soliman
# 4      Consumer Services                                     Kevin Flannery
# ..                   ...                                                ...
# 490      Online Services  Beatrice Fischel-Bock, Madeine Fraser & Lizzie...
# 491       Toys and Games                                        Chris Ruder
# 492   Outdoor Recreation                   David Patrick and Zack Fleishman
# 493        Entertainment                                    Adriana Montano
# 494           Automotive                                         Joe Wilcox
#
#              location                              website  askedfor  \
# 0        St. Paul, MN                                 None   1000000
# 1        Somerset, NJ                  http://whybake.com/    460000
# 2         Atlanta, GA       http://www.avatheelephant.com/     50000
# 3           Tampa, FL  http://collegehunkshaulingjunk.com/    250000
# 4            Cary, NC              http://www.wispots.com/   1200000
# ..                ...                                  ...       ...
# 490  Philadelphia, PA            https://zoominteriors.com    100000
# 491       Chicago, IL                 http://spikeball.com    500000
# 492   Lake Forest, CA            http://www.sharkwheel.com    100000
# 493    Boca Raton, FL           http://gatocafeflorida.com    100000
# 494     Palo Alto, CA       http://www.swaymotorsports.com    300000
#
#      exchangeforstake  valuation  season            shark1            shark2  \
# 0                  15    6666667       1  Barbara Corcoran   Robert Herjavec
# 1                  10    4600000       1  Barbara Corcoran   Robert Herjavec
# 2                  15     333333       1  Barbara Corcoran   Robert Herjavec
# 3                  25    1000000       1  Barbara Corcoran   Robert Herjavec
# 4                  10   12000000       1  Barbara Corcoran   Robert Herjavec
# ..                ...        ...     ...               ...               ...
# 490                20     500000       6      Lori Greiner  Barbara Corcoran
# 491                10    5000000       6      Lori Greiner     Kevin O'Leary
# 492                 5    2000000       6      Lori Greiner     Kevin O'Leary
# 493                20     500000       6      Lori Greiner     Kevin O'Leary
# 494                10    3000000       6      Lori Greiner     Kevin O'Leary
#
#               shark3         shark4            shark5  \
# 0      Kevin O'Leary   Daymond John  Kevin Harrington
# 1      Kevin O'Leary   Daymond John  Kevin Harrington
# 2      Kevin O'Leary   Daymond John  Kevin Harrington
# 3      Kevin O'Leary   Daymond John  Kevin Harrington
# 4      Kevin O'Leary   Daymond John  Kevin Harrington
# ..               ...            ...               ...
# 490  Robert Herjavec  Kevin O'Leary        Mark Cuban
# 491     Daymond John     Mark Cuban      Nick Woodman
# 492     Daymond John     Mark Cuban      Nick Woodman
# 493     Daymond John     Mark Cuban      Nick Woodman
# 494     Daymond John     Mark Cuban      Nick Woodman
#
#                            title episode_season  multiple_entreprenuers
# 0                      Ionic Ear     2020-01-01                   False
# 1          Mr. Tod's Pie Factory     2020-01-01                   False
# 2               Ava the Elephant     2020-01-01                   False
# 3    College Foxes Packing Boxes     2020-01-01                   False
# 4                        Wispots     2020-01-01                   False
# ..                           ...            ...                     ...
# 490               Zoom Interiors     2020-06-28                   False
# 491                    Spikeball     2020-06-29                   False
# 492                  Shark Wheel     2020-06-29                    True
# 493                    Gato Cafe     2020-06-29                   False
# 494             Sway Motorsports     2020-06-29                   False
#
# [495 rows x 20 columns]
