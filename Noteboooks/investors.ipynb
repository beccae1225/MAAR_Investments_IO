# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from config import username, password, host, port
import requests

# %%
# create an engine that can connect to local database
engine = create_engine(f"postgresql://{username}:{password}@{host}:{port}/postgres")
conn=engine.connect()

# %%
##read in salaries and their count from sql
billionaire_list = pd.read_sql('SELECT * FROM billionaires group by name order by name;',conn)

# %%
billionaire_list
# Out:
#                               name  rank  year company_founded  \
# 0             A. Jerrold Perenchio   663  2014            1955
# 1               Abdulla Al Futtaim   687  2014            1930
# 2     Abdulla bin Ahmad Al Ghurair   305  2014            1960
# 3                Abdullah Al Rajhi   731  2014            1957
# 4                 Abdulsamad Rabiu  1372  2014            1988
# ...                            ...   ...   ...             ...
# 1648                     Zhu Yicai  1154  2014            1993
# 1649                 Ziyad Manasir   609  2014            1992
# 1650            Ziyaudin Magomedov  1372  2014            2004
# 1651                  Zong Qinghou    94  2014            1987
# 1652            Zygmunt Solorz-Zak   446  2014            1992
#
#                company_name     company_relationship        company_sector  \
# 0                 Univision  former chairman and CEO                 media
# ...

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "768", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)

# %%
data=response.text

# %%
parsed=json.loads(data)
results=parsed['results']

# %%
print(json.dumps(parsed, indent=4))
# Out:
# {
#     "meta": {
#         "total_record_count": 38386,
#         "total_pages": 768,
#         "current_page": 768,
#         "per_page": 50
#     },
#     "query_id": "l8WfDjWiZF3tdZ1T0bGzfIayzZby4zlZ8PabVF7W4KsnSKYdolsfkvs1knp4WbelnwQrtsTs9lTtyI7d8Zg=",
#     "query": {
#         "urlsafe_query_hash": "l8WfDjWiZF3tdZ1T0bGzfIayzZby4zlZ8PabVF7W4KsnSKYdolsfkvs1knp4WbelnwQrtsTs9lTtyI7d8Zg=",
#         "dataset": "investor",
#         "filter": {
#             "investor_id": {
#                 "gte": 0
#             }
#         },
#         "sort": null
#     },
#     "results": [
#         {
#             "investor_id": 12564,
#             "name": "Anupam Mittal",
#             "investor_domain": null,
#             "location": "Mumbai",
#             "three_year_funds_offered": 0,
#             "three_year_funds_sold": 0,
#             "est_most_recent_fund_date": null,
#             "type": "angel",
#             "most_recent_deal": "2020-05-12",
# ...

# %%
with open('results.json', 'w') as f:
    json.dump(results, f)

# %%
investors_df = pd.read_json('results.json')

# %%
investors_df.head()
# Out:
#    investor_id              name        investor_domain   location  \
# 0        12564     Anupam Mittal                   None     Mumbai
# 1        27804  Gopal Srinivasan                   None       None
# 2        32675        Atul Birla                   None       None
# 3         7170   Initial:Capital     initialcapital.com       None
# 4        10789  e.Bricks Digital  ebricksdigital.com.br  São Paulo
#
#    three_year_funds_offered  three_year_funds_sold est_most_recent_fund_date  \
# 0                         0                      0                      None
# 1                         0                      0                      None
# 2                         0                      0                      None
# 3                         0                      0                      None
# 4                         0                      0                      None
#
#     type most_recent_deal  number_of_deals  portfolio_size  avg_growth_score  \
# ...

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "767", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df1 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "766", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df2 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "765", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df3 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "764", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df4 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "763", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df5 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "762", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df6 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "761", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df7 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "760", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df8 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "759", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df9 = pd.read_json('results.json')

# %%
df1=pd.concat([investors_df, investors_df1, investors_df2, investors_df3, investors_df4, investors_df5, investors_df6, investors_df7, investors_df8, investors_df9])
print(len(df1))
# Out:
# 486

# %%
df1.reset_index()
# Out:
#      index  investor_id                       name        investor_domain  \
# 0        0        12564              Anupam Mittal                   None
# 1        1        27804           Gopal Srinivasan                   None
# 2        2        32675                 Atul Birla                   None
# 3        3         7170            Initial:Capital     initialcapital.com
# 4        4        10789           e.Bricks Digital  ebricksdigital.com.br
# ..     ...          ...                        ...                    ...
# 481     45          262            Trident Capital         tridentcap.com
# 482     46          224              Eden Ventures     edenventures.co.uk
# 483     47        34183  Cybersecurity Investments                   None
# 484     48         8286                 CBRE Group               cbre.com
# 485     49          313                  T-Venture          t-venture.com
#
#       location  three_year_funds_offered  three_year_funds_sold  \
# ...

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "758", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df10 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "757", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df11 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "756", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df12 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "755", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df13 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "754", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df14 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "753", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df15 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "752", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df16 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "751", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df17 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "750", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df18 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "749", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df19 = pd.read_json('results.json')

# %%
import requests

url = "https://api.mattermark.com/queries"

querystring = {"industries":"food & beverages","dataset": "investor","page": "748", "per_page": "50"}

headers = {
    "content-type": "application/json",
    "authorization": "37505a5e0ab3a2fdc70779e527f5a05fb508df8db47643f5218b96ae5c704059"
}

response = requests.request("POST", url, headers=headers, params=querystring)
data=response.text
parsed=json.loads(data)
results=parsed['results']
# print(json.dumps(parsed, indent=4))
with open('results.json', 'w') as f:
    json.dump(results, f)
investors_df20 = pd.read_json('results.json')

# %%
df2=pd.concat([df1, investors_df10, investors_df11, investors_df12, investors_df13, investors_df14, investors_df15, investors_df16, investors_df17, investors_df18, investors_df19, investors_df20])
print(len(df2))
# Out:
# 1036

# %%
df3 = df2.dropna(subset=['city','country'])
print(len(df3))
# Out:
# 312

# %%
df3.reset_index()
# Out:
#      index  investor_id                  name        investor_domain  \
# 0        0        12564         Anupam Mittal                   None
# 1        4        10789      e.Bricks Digital  ebricksdigital.com.br
# 2        5          231       Carmel Ventures     carmelventures.com
# 3        6        11256       Anand Ladsariya                   None
# 4        8        25916       Venture Nursery     venturenursery.com
# ..     ...          ...                   ...                    ...
# 307     14        10051        Mike Hirshland                   None
# 308     20         8445       Gordon Paddison                   None
# 309     26        12704        Raine Ventures              raine.com
# 310     31         9741       Alex Richardson                   None
# 311     46         7694  Huron River Ventures       huronrivervc.com
#
#         location  three_year_funds_offered  three_year_funds_sold  \
# 0         Mumbai                         0                      0
# ...

# %%
df4=df3[["investor_id", "name", "location", "type", "most_recent_deal", "number_of_deals", "portfolio_size", "city", "state",
         "country", "website"
]]
print(len(df3))
# Out:
# 312

# %%
df4['industry'] ='food & beverages'
# Out:
# C:\Users\ssbne\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final_investors_df = df4
final_investors_df
# Out:
#     investor_id                  name     location         type  \
# 0         12564         Anupam Mittal       Mumbai        angel
# 4         10789      e.Bricks Digital    São Paulo           vc
# 5           231       Carmel Ventures    Herzeliya           vc
# 6         11256       Anand Ladsariya       Mumbai        angel
# 8         25916       Venture Nursery       Mumbai  accelerator
# ..          ...                   ...          ...          ...
# 14        10051        Mike Hirshland     Bay Area        angel
# 20         8445       Gordon Paddison  Los Angeles        angel
# 26        12704        Raine Ventures     Bay Area           vc
# 31         9741       Alex Richardson       Boston        angel
# 46         7694  Huron River Ventures      Detroit           vc
#
#    most_recent_deal  number_of_deals  portfolio_size           city state  \
# 0        2020-05-12                0               0         Mumbai  None
# ...

# %%
final_investors_df.to_csv("Data Sets/api1.csv")

# %%
# create an engine that can connect to local database
engine = create_engine(f"postgresql://{username}:{password}@{host}:{port}/postgres")
conn=engine.connect()

# %%
##read in salaries and their count from sql
sharkTank_list = pd.read_sql('SELECT * FROM sharktank;',conn)

# %%
sharkTank_list
# Out:
#       deal                                        description  episode  \
# 0    False             Bluetooth device implant for your ear.        1
# 1     True  Retail and wholesale pie factory with two reta...        1
# 2     True  Ava the Elephant is a godsend for frazzled par...        1
# 3    False  Organizing, packing, and moving services deliv...        1
# 4    False  Interactive media centers for healthcare waiti...        1
# ..     ...                                                ...      ...
# 490   True  Zoom Interiors is a virtual service for interi...       28
# 491   True  Spikeball started out as a casual outdoors gam...       29
# 492   True  Shark Wheel is out to literally reinvent the w...       29
# 493  False  Adriana Montano wants to open the first Cat Ca...       29
# 494   True  Sway Motorsports makes a three-wheeled, all-el...       29
#
#                 category                                      entrepreneurs  \
# ...

# %%
inner_merged_total = pd.merge(billionaires_list, investors_list, on=["name"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-6a22b0004124> in <module>
# ----> 1 inner_merged_total = pd.merge(billionaires_list, investors_list, on=["name"])
#
# NameError: name 'billionaires_list' is not defined
